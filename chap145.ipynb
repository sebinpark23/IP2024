# %% [markdown]
# ##### Chap 1.4.5 Morphological Transformations

# %% [markdown]
# ##### Chap 1.4.5 Morphological Transformations

# %% [markdown]
# ##### 1. Erosion

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('j.png',0)
kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(erosion),plt.title('Output')
# Out:
# (<Axes: title={'center': 'Output'}>,
#  <matplotlib.image.AxesImage at 0x214b41b2400>,
#  Text(0.5, 1.0, 'Output'))

# %% [markdown]
# ##### 2. Dilation

# %%
img = cv2.imread('j.png',0)
kernel = np.ones((5,5),np.uint8)

dilation = cv2.dilate(img,kernel,iterations = 2)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dilation),plt.title('Output')
# Out:
# (<Axes: title={'center': 'Output'}>,
#  <matplotlib.image.AxesImage at 0x214b6909670>,
#  Text(0.5, 1.0, 'Output'))

# %% [markdown]
# ##### 3. Opening

# %%
img = cv2.imread('j2.png')
kernel = np.ones((5,5),np.uint8)

opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(opening),plt.title('Output')
# Out:
# (<Axes: title={'center': 'Output'}>,
#  <matplotlib.image.AxesImage at 0x214b68f6310>,
#  Text(0.5, 1.0, 'Output'))

# %% [markdown]
# ##### 4. Closing

# %%
img = cv2.imread('j3.png')
kernel = np.ones((5,5),np.uint8)

closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(closing),plt.title('Output')
# Out:
# (<Axes: title={'center': 'Output'}>,
#  <matplotlib.image.AxesImage at 0x214b7056520>,
#  Text(0.5, 1.0, 'Output'))
